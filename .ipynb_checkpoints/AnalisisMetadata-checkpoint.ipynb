# %% [markdown]
# # Análisis Estadístico de los datos
# En este notebook nos centraremos en analizar el archivo `OTUS_conservados.csv`

# %%
#! pip install contextily geopandas matplotlib numpy pandas seaborn

# %%
import contextily as ctx
import geopandas as gpd
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
import pandas as pd 
import seaborn as sns
from sklearn.decomposition import PCA

# %% [markdown]
# ## Lectura de datos

# %%
data_path = "./data"

# %%
metadata = pd.read_csv(f"{data_path}/metadata_agave_clavi_solena - metadata.csv", index_col="sample_id")
metadata["plant_part"] = metadata["plant_part"].apply(lambda x: str(x).lower())
metadata.head()
# Out:
#              Experiment Assay Type seq_type                Organism  \
# sample_id
# SRR10127267  SRX6855687        WGS  Shotgun        plant metagenome
# SRR10127271  SRX6855691        WGS  Shotgun        plant metagenome
# SRR10591223  SRX7271075        WGA      16S  rhizosphere metagenome
# SRR10591224  SRX7271074        WGA      16S  rhizosphere metagenome
# SRR10591225  SRX7271073        WGA      16S  rhizosphere metagenome
#
#               plant_part                    host_name  latitude  longitude  \
# sample_id
# SRR10127267  phylosphere              Agave Tequilana   21.7658   -100.163
# SRR10127271  phylosphere  Myrtillocactus Geometrizans   21.7658   -100.163
# SRR10591223  rhizosphere     Cephalocereus polylophus   20.5900   -100.380
# SRR10591224  rhizosphere     Cephalocereus polylophus   20.5900   -100.380
# SRR10591225  rhizosphere     Cephalocereus polylophus   20.5900   -100.380
#
#                   state country      continent
# sample_id
# SRR10127267     Jalisco  Mexico  North America
# SRR10127271  Guanajuato  Mexico  North America
# SRR10591223   Queretaro  Mexico  North America
# SRR10591224   Queretaro  Mexico  North America
# SRR10591225   Queretaro  Mexico  North America

# %% [markdown]
# ## Información básica

# %%
metadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 289 entries, SRR10127267 to t-nG3jM2TOMPOOA051345
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Experiment  252 non-null    object
#  1   Assay Type  252 non-null    object
#  2   seq_type    249 non-null    object
#  3   Organism    248 non-null    object
#  4   plant_part  289 non-null    object
#  5   host_name   289 non-null    object
#  6   latitude    287 non-null    float64
#  7   longitude   287 non-null    float64
#  8   state       260 non-null    object
#  9   country     287 non-null    object
#  10  continent   287 non-null    object
# dtypes: float64(2), object(9)
# memory usage: 27.1+ KB

# %%
metadata.describe()
# Out:
#          latitude   longitude
# count  287.000000  287.000000
# mean    28.564543    9.063473
# std     13.357131  107.602231
# min    -26.110000 -122.759800
# 25%     22.640250 -101.267029
# 50%     34.248700   27.330000
# 75%     36.750000  115.200000
# max     56.000000  127.970000

# %% [markdown]
# ## Mapas

# %%
metadata_gdf = gpd.GeoDataFrame(metadata.copy(), geometry=gpd.points_from_xy(metadata['longitude'], metadata['latitude']), crs='EPSG:4326')
metadata_gdf
# Out:
#                        Experiment Assay Type seq_type                Organism  \
# sample_id
# SRR10127267            SRX6855687        WGS  Shotgun        plant metagenome
# SRR10127271            SRX6855691        WGS  Shotgun        plant metagenome
# SRR10591223            SRX7271075        WGA      16S  rhizosphere metagenome
# SRR10591224            SRX7271074        WGA      16S  rhizosphere metagenome
# SRR10591225            SRX7271073        WGA      16S  rhizosphere metagenome
# ...                           ...        ...      ...                     ...
# t-AYtCM2TOMPOOA100360         NaN        NaN      NaN                     NaN
# t-DYZgM2TOMPOOB100370         NaN        NaN      NaN                     NaN
# t-eBCjM2CHIPOOBXX1180         NaN        NaN      NaN                     NaN
# t-j1iWM2CHIPOOBXX1561         NaN        NaN      NaN                     NaN
# t-nG3jM2TOMPOOA051345         NaN        NaN      NaN                     NaN
#
#                         plant_part                    host_name   latitude  \
# sample_id
# SRR10127267            phylosphere              Agave Tequilana  21.765800
# SRR10127271            phylosphere  Myrtillocactus Geometrizans  21.765800
# SRR10591223            rhizosphere     Cephalocereus polylophus  20.590000
# SRR10591224            rhizosphere     Cephalocereus polylophus  20.590000
# SRR10591225            rhizosphere     Cephalocereus polylophus  20.590000
# ...                            ...                          ...        ...
# t-AYtCM2TOMPOOA100360          nan         Solanum lycopersicum  21.019015
# t-DYZgM2TOMPOOB100370          nan         Solanum lycopersicum  21.019015
# t-eBCjM2CHIPOOBXX1180          nan                     Capsicum  25.172109
# t-j1iWM2CHIPOOBXX1561          nan                     Capsicum  25.172109
# t-nG3jM2TOMPOOA051345          nan         Solanum lycopersicum  25.172109
#
#                         longitude       state country      continent  \
# sample_id
# SRR10127267           -100.163000     Jalisco  Mexico  North America
# SRR10127271           -100.163000  Guanajuato  Mexico  North America
# SRR10591223           -100.380000   Queretaro  Mexico  North America
# SRR10591224           -100.380000   Queretaro  Mexico  North America
# SRR10591225           -100.380000   Queretaro  Mexico  North America
# ...                           ...         ...     ...            ...
# t-AYtCM2TOMPOOA100360 -101.257359  Guanajuato  Mexico  North America
# t-DYZgM2TOMPOOB100370 -101.257359  Guanajuato  Mexico  North America
# t-eBCjM2CHIPOOBXX1180 -107.479517     Sinaloa  Mexico  North America
# t-j1iWM2CHIPOOBXX1561 -107.479517     Sinaloa  Mexico  North America
# t-nG3jM2TOMPOOA051345 -107.479517     Sinaloa  Mexico  North America
#
#                                           geometry
# sample_id
# SRR10127267            POINT (-100.16300 21.76580)
# SRR10127271            POINT (-100.16300 21.76580)
# SRR10591223            POINT (-100.38000 20.59000)
# SRR10591224            POINT (-100.38000 20.59000)
# SRR10591225            POINT (-100.38000 20.59000)
# ...                                            ...
# t-AYtCM2TOMPOOA100360  POINT (-101.25736 21.01901)
# t-DYZgM2TOMPOOB100370  POINT (-101.25736 21.01901)
# t-eBCjM2CHIPOOBXX1180  POINT (-107.47952 25.17211)
# t-j1iWM2CHIPOOBXX1561  POINT (-107.47952 25.17211)
# t-nG3jM2TOMPOOA051345  POINT (-107.47952 25.17211)
#
# [289 rows x 12 columns]

# %%
fig, ax = plt.subplots(1, figsize=(15, 15))

metadata_gdf.plot(marker='.', c='darkgreen', ax=ax, markersize=70, zorder=1)

plt.title("Localización de las muestras",fontsize=30)

plt.axis("off")


ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs='EPSG:4326')

# %%
fig, ax = plt.subplots(1, figsize=(15, 15))

metadata_gdf.plot(marker='.', column='plant_part', ax=ax, markersize=70, zorder=1, legend=True)

plt.title("Localización de las muestras por parte de la planta",fontsize=30)

plt.axis("off")


ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs='EPSG:4326')

# %%
fig, ax = plt.subplots(1, figsize=(15, 15))

metadata_gdf.plot(marker='.', column='Organism', ax=ax, markersize=70, zorder=1, legend=True)

plt.title("Localización de las muestras por organismo",fontsize=30)

plt.axis("off")


ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron, crs='EPSG:4326')

# %% [markdown]
# ## Gráficas

# %% [markdown]
# **Distribución de *hosts***

# %%
metadata["host_name"].value_counts()
# Out:
# Zea mays                                  79
# Solanum tuberosum                         60
# Solanum lycopersicum                      29
# Soil of Zea mays and Triticum rotation    22
# Capsicum                                  19
# Medicago sativa                           18
# Dioon Merolae                              8
# Cephalocereus polylophus                   6
# Echinocactus Platyacanthus                 6
# Solanum Lycopersicum                       5
# Soil                                       4
# Capsicum annuum                            4
# Agave Tequilana                            4
# Myrtillocactus Geometrizans                4
# Opuntia Robusta                            4
# Agave Salmiana                             4
# Poaceae                                    4
# Capsicum annuum var. annuum                3
# Phaseolus Vulgaris                         2
# Asteraceae                                 1
# not applicable                             1
# Fagales                                    1
# Macroptilium Atropurpureum                 1
# Name: host_name, dtype: int64

# %%
fig, ax = plt.subplots(1,1 ,figsize=(15, 20))
sns.countplot(data=metadata, y="host_name", order=metadata["host_name"].value_counts().index, color="darkgreen")
plt.xlabel("Frecuencia")
plt.ylabel("Planta")
plt.title("Distribución de plantas host", fontsize=21)
plt.show()

# %% [markdown]
# **Distribución de *países***

# %%
metadata["country"].value_counts()
# Out:
# China           136
# Mexico           86
# USA              45
# South Africa     10
# Peru              4
# Korea             3
# Netherlands       2
# Denmark           1
# Name: country, dtype: int64

# %%
fig, ax = plt.subplots(1,1 ,figsize=(15, 20))
sns.countplot(data=metadata, y="country", order=metadata["country"].value_counts().index, color="darkgreen")
plt.xlabel("Frecuencia")
plt.ylabel("País")
plt.title("Distribución de países", fontsize=21)
plt.show()

# %% [markdown]
# **Distribución de *estados***

# %%
metadata["state"].value_counts()
# Out:
# Jiaozhou           57
# Sinaloa            27
# Hengshui City      22
# Xingtai City       20
# California         19
# Guanajuato         18
# Huishui            12
# Queretaro          12
# Texas              12
# Alabama            10
# Chiapas             8
# Aguascalientes      6
# Randfontein         5
# Lichtenburg         5
# Jalisco             5
# Peru                4
# Hoengseong          3
# Nanjing             3
# Edo. Mex.           3
# San Luis Potosi     3
# Durango             3
# Wageningen          2
# Nayarit             1
# Name: state, dtype: int64

# %%
fig, ax = plt.subplots(1,1 ,figsize=(15, 20))
sns.countplot(data=metadata, y="state", order=metadata["state"].value_counts().index, color="darkgreen")
plt.xlabel("Frecuencia")
plt.ylabel("Estado")
plt.title("Distribución de estados", fontsize=21)
plt.show()

# %% [markdown]
# **Distribución de *partes de las plantas***

# %%
metadata["plant_part"].value_counts()
# Out:
# nan               139
# rhizosphere        64
# phyllosphere       31
# geocaulosphere     28
# root-zone          10
# furrow              9
# phylosphere         8
# Name: plant_part, dtype: int64

# %%
fig, ax = plt.subplots(1,1 ,figsize=(15, 20))
sns.countplot(data=metadata, y="plant_part", order=metadata["plant_part"].value_counts().index, color="darkgreen")
plt.xlabel("Frecuencia")
plt.ylabel("Planta")
plt.title("Distribución de climas", fontsize=21)
plt.show()
