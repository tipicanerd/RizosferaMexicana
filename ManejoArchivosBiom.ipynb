# %%
import os
import pandas as pd

# %%
metadata = pd.read_csv("data/metadata_agave_clavi_solena - metadata.csv")
metadata
# Out:
#                  sample_id  Experiment Assay Type seq_type  \
# 0              SRR10127267  SRX6855687        WGS  Shotgun
# 1              SRR10127271  SRX6855691        WGS  Shotgun
# 2              SRR10591223  SRX7271075        WGA      16S
# 3              SRR10591224  SRX7271074        WGA      16S
# 4              SRR10591225  SRX7271073        WGA      16S
# ..                     ...         ...        ...      ...
# 284  t-AYtCM2TOMPOOA100360         NaN        NaN      NaN
# 285  t-DYZgM2TOMPOOB100370         NaN        NaN      NaN
# 286  t-eBCjM2CHIPOOBXX1180         NaN        NaN      NaN
# 287  t-j1iWM2CHIPOOBXX1561         NaN        NaN      NaN
# 288  t-nG3jM2TOMPOOA051345         NaN        NaN      NaN
#
#                    Organism   plant_part                    host_name  \
# 0          plant metagenome  Phylosphere              Agave Tequilana
# 1          plant metagenome  Phylosphere  Myrtillocactus Geometrizans
# ...

# %%
otros = [file[:file.index(".")] for file in os.listdir("bioms/OtrosMexicanos/")]
otros
# Out:
# ['agave',
#  'all-data-130223',
#  'all-data',
#  'chile',
#  'maiz',
#  'SRR10127267',
#  'SRR10127271',
#  'SRR10591223',
#  'SRR10591224',
#  'SRR10591225',
#  'SRR10591226',
#  'SRR10591227',
#  'SRR10591228',
#  'SRR10591229',
#  'SRR10591230',
#  'SRR10591231',
#  'SRR10591232',
#  'SRR10591233',
#  'SRR10591234',
#  'SRR11092496',
#  'SRR11092498',
#  'SRR11092499',
#  'SRR11092501',
#  'SRR11092502',
#  'SRR11092505',
#  'SRR11092506',
#  'SRR11092508',
#  'SRR11092509',
#  'SRR11092511',
#  'SRR11092512',
#  'SRR4140275',
#  'SRR4140276',
#  'SRR4140277',
#  'SRR4140278',
#  'SRR4141180',
#  'SRR4142282',
#  'SRR4142283',
#  'SRR4142417',
#  'SRR4142418',
#  'SRR4142430',
#  'SRR4142433',
#  'SRR4142459',
#  'SRR4142460',
#  'SRR5166355',
#  'SRR5240833',
#  'SRR5240836',
#  'SRR5240837',
#  'SRR5240884',
#  'SRR5240885',
#  'SRR5240886',
#  'SRR5240887',
#  'SRR5240888',
#  'SRR5829600',
#  'SRR5829603',
#  'SRR5829609',
#  'tomate']

# %%
solena = [file[:file.index(".")] for file in os.listdir("bioms/Solena/")]
solena
# Out:
# ['t-0n7bM2TOMPOOA100365',
#  't-1ayWM2CHIPOOB100705',
#  't-1qGgM2TOMPOOM080340',
#  't-3xfYM2CHIPOOA051365',
#  't-9JUZM2TOMPOOB100355',
#  't-a50wM2TOMPOOB051350',
#  't-abKIM2TOMPOOA051320',
#  't-aFJgM2TOMPOOM090325',
#  't-AJwcM2MAIPOOA100700',
#  't-AYtCM2TOMPOOA100360',
#  't-B7zTM2MAIPOOA070610',
#  't-c5isM2MAIPOOA070615',
#  't-cSObM2TOMPOOM080315',
#  't-cuu6M2TOMPOOB051315',
#  't-dSz8M2TOMPOOA051340',
#  't-DYZgM2TOMPOOB100370',
#  't-eBCjM2CHIPOOBXX1180',
#  't-FvY2M2TOMPOOB051329',
#  't-hoQoM2CHIPOOA051115',
#  't-Ia7iM2MAIPOOB100245',
#  't-IGpcM2TOMPOOB051290',
#  't-iYASM2TOMPOOA050195',
#  't-j1iWM2CHIPOOBXX1561 (1)',
#  't-j1iWM2CHIPOOBXX1561',
#  't-jYxWM2CHIPOOB051110',
#  't-nG3jM2TOMPOOA051345',
#  't-Nm8MM2TOMPOOA051300',
#  't-oAVVM2CHIPOOB051360',
#  't-OeS0M2TOMPOOA051355',
#  't-P0ZQM2MAIPOOA100240',
#  't-pse1M2MAIPOOA100685',
#  't-qU3SM2MAIPOOM070605',
#  't-s9OmM2TOMPOOB051285',
#  't-TECcM2TOMPOOA051310',
#  't-TgLUM2MAIPOOM070620',
# ...

# %%
clavibacter = [[file[:file.index(".")] for file in os.listdir(f"bioms/Clavibacter/{folder}")] for folder in os.listdir("bioms/Clavibacter/")]
clavibacter = [file_id for folder in clavibacter for file_id in folder]
clavibacter
# Out:
# ['choi-2020',
#  'miscelaneous-capsicum',
#  'newberry-2020',
#  'barajas-2020',
#  'newberry-2020',
#  'shi-2019',
#  'akinola-2021',
#  'miscellaneous-mays',
#  'x-wu-2021',
#  'xiong-2021']

# %% [markdown]
# ## Archivos faltantes

# %%
metadata[metadata['sample_id'].isin(otros+solena)]
# Out:
#                  sample_id  Experiment Assay Type seq_type  \
# 0              SRR10127267  SRX6855687        WGS  Shotgun
# 1              SRR10127271  SRX6855691        WGS  Shotgun
# 2              SRR10591223  SRX7271075        WGA      16S
# 3              SRR10591224  SRX7271074        WGA      16S
# 4              SRR10591225  SRX7271073        WGA      16S
# ..                     ...         ...        ...      ...
# 284  t-AYtCM2TOMPOOA100360         NaN        NaN      NaN
# 285  t-DYZgM2TOMPOOB100370         NaN        NaN      NaN
# 286  t-eBCjM2CHIPOOBXX1180         NaN        NaN      NaN
# 287  t-j1iWM2CHIPOOBXX1561         NaN        NaN      NaN
# 288  t-nG3jM2TOMPOOA051345         NaN        NaN      NaN
#
#                    Organism   plant_part                    host_name  \
# 0          plant metagenome  Phylosphere              Agave Tequilana
# 1          plant metagenome  Phylosphere  Myrtillocactus Geometrizans
# ...
